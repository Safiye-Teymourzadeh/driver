# %%
import numpy as np
import pandas as pd
import astropy.io.fits as fits
# import healpy as hp
from scipy import integrate
import matplotlib.pyplot as plt
from astropy.cosmology import Planck15 as cosmo
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit

# %%
# Loading the data
galaxy_catalog_raw = fits.open('/home/farnoosh/Nextcloud/Master_Thesis_all/codes/data/GAMA/merged/StellarMass-gkvScience/mergedStellarMass-gkvScience')[1].data  # galaxies
efeds_raw = fits.open('/home/farnoosh/Nextcloud/Master_Thesis_all/codes/data/eFEDS/Mathias_Klug/efeds_members.fit')[1].data  # clusters

# %%
print(len(efeds_raw))
# Out:
# 542

# %%
# Masks
cluster_mask = (
    ~np.isnan(efeds_raw['VDISP'])  # mask clusters which doesn't have VDISP values
)

galaxy_mask = (
        (galaxy_catalog_raw['uberclass'] == 1) &  #galaxy
        (galaxy_catalog_raw['duplicate'] == False) &
        (galaxy_catalog_raw['mask'] == False) &
        (galaxy_catalog_raw['NQ'] > 2) &
        (galaxy_catalog_raw['SC'] > 7) &
        (galaxy_catalog_raw['mstar'] > 0) &
        (galaxy_catalog_raw['RAcen'] > 126.5) &
        (galaxy_catalog_raw['RAcen'] < 145.1) &
        (galaxy_catalog_raw['Deccen'] > -2.6) &
        (galaxy_catalog_raw['Deccen'] < 5.8) &
        (galaxy_catalog_raw['Z'] < 1.31) &
        (galaxy_catalog_raw['starmask'] == False)
)

galaxy_catalog = galaxy_catalog_raw[galaxy_mask]
efeds_catalog = efeds_raw[cluster_mask]
print('number of the galaxies after masking: ', len(galaxy_catalog))
print('number of the clusters after masking: ', len(efeds_catalog))
# Out:
# number of the galaxies after masking:  36801
# number of the clusters after masking:  282

# %%
# Constants
H0 = 70
c = 3e5
arcmin_to_rad = np.pi / 180 / 60

# %%
# Functions
def distance_from_redshift(z):
    return c * z / H0

def cluster_volume(cluster_radius_Mpc):
    return (4/3) * np.pi * cluster_radius_Mpc**3

def angular_separation(ra1, dec1, ra2, dec2):
    ra1, dec1, ra2, dec2 = map(np.radians, [ra1, dec1, ra2, dec2])
    delta_RA = ra2 - ra1
    delta_DEC = dec2 - dec1
    w = np.sin(delta_DEC/2.0)**2 + np.cos(dec1) * np.cos(dec2) * np.sin(delta_RA/2.0)**2
    return 2 * np.arcsin(np.sqrt(w))

def projected_distance(cluster_ra, cluster_dec, cluster_z, galaxy_ra, galaxy_dec):
    angular_dist = angular_separation(cluster_ra, cluster_dec, galaxy_ra, galaxy_dec)
    D_A = cosmo.angular_diameter_distance(cluster_z).value
    projected_distance_Mpc = D_A * angular_dist
    return projected_distance_Mpc

def is_galaxy_in_cluster(galaxy_ra, galaxy_dec, galaxy_z, cluster_ra, cluster_dec, cluster_z, cluster_radius_Mpc):
    projected_dist_Mpc = projected_distance(cluster_ra, cluster_dec, cluster_z, galaxy_ra, galaxy_dec)
    return projected_dist_Mpc <= 2 * cluster_radius_Mpc

def redshift_comparison(cluster_z, cluster_Velocity_Dispersion, galaxy_z, threshold_factor=1):
    delta_z = (cluster_Velocity_Dispersion / c) * threshold_factor
    return np.abs(galaxy_z - cluster_z) <= delta_z

def add_position_passed_galaxies_column(cluster_df, galaxy_df):
    position_passed_galaxies_list = []
    num_position_passed_galaxies_list = []

    galaxy_df['cluster_ID'] = None

    for i, cluster in cluster_df.iterrows():
        position_passed_galaxies_cluster = []
        for j, galaxy in galaxy_df.iterrows():
            if is_galaxy_in_cluster(galaxy['RA'], galaxy['DEC'], galaxy['z'], cluster['RA'], cluster['DEC'], cluster['z'], cluster['cluster_radius_Mpc']):
                position_passed_galaxies_cluster.append(galaxy['g_ID'])
                galaxy_df.loc[galaxy_df['g_ID'] == galaxy['g_ID'], 'cluster_ID'] = cluster['c_ID']

        position_passed_galaxies_list.append(position_passed_galaxies_cluster)
        num_position_passed_galaxies_list.append(len(position_passed_galaxies_cluster))
        print(f"Cluster {cluster['c_NAME']} has {len(position_passed_galaxies_cluster)} galaxies that passed positional comparison")

    cluster_df['position_passed_galaxies'] = position_passed_galaxies_list
    cluster_df['num_position_passed_galaxies'] = num_position_passed_galaxies_list

    return cluster_df, galaxy_df

def add_z_passed_galaxies_column(cluster_df, galaxy_df, threshold_factor=1):
    z_passed_galaxies_list = []
    num_passed_galaxies_list = []

    for i, cluster in cluster_df.iterrows():
        position_passed_galaxies = cluster['position_passed_galaxies']
        passed_galaxies_cluster = []

        for g_id in position_passed_galaxies:
            galaxy = galaxy_df[galaxy_df['g_ID'] == g_id].iloc[0]
            if redshift_comparison(cluster['z'], cluster['cluster_Velocity_Dispersion'], galaxy['z'], threshold_factor):
                passed_galaxies_cluster.append(galaxy['g_ID'])

        z_passed_galaxies_list.append(passed_galaxies_cluster)
        num_passed_galaxies_list.append(len(passed_galaxies_cluster))
        print(f"Cluster {cluster['c_NAME']} has {len(passed_galaxies_cluster)} galaxies that passed redshift comparison")

    cluster_df['z_passed_galaxies'] = z_passed_galaxies_list
    cluster_df['num_passed_galaxies'] = num_passed_galaxies_list
    cluster_df['galaxies_within'] = z_passed_galaxies_list

    return cluster_df

# %%
# Dataframes
cluster_df = pd.DataFrame({
    'c_ID': efeds_catalog['ID-SRC'].byteswap().newbyteorder(),
    'c_NAME': efeds_catalog['NAME'].byteswap().newbyteorder(),
    'RA': efeds_catalog['RA'].byteswap().newbyteorder(),
    'DEC': efeds_catalog['DEC'].byteswap().newbyteorder(),
    'z': efeds_catalog['ZBEST'].byteswap().newbyteorder(),
    'distance_Mpc': distance_from_redshift(efeds_catalog['ZBEST'].byteswap().newbyteorder()),
    'cluster_radius_Mpc': efeds_catalog['R_LAMBDA'].byteswap().newbyteorder(),
    'cluster_volume_Mpc3': cluster_volume(efeds_catalog['R_LAMBDA'].byteswap().newbyteorder()),
    'cluster_Velocity_Dispersion': efeds_catalog['VDISP'].byteswap().newbyteorder()
})

galaxy_df = pd.DataFrame({
    'g_ID': galaxy_catalog['uberID'].byteswap().newbyteorder(),
    'RA': galaxy_catalog['RAcen'].byteswap().newbyteorder(),
    'DEC': galaxy_catalog['Deccen'].byteswap().newbyteorder(),
    'z': galaxy_catalog['Z'].byteswap().newbyteorder()
})

# %%
print(cluster_df)
# Out:
#       c_ID                 c_NAME         RA      DEC       z  distance_Mpc  \
# 0     4800  eFEDSJ082808.7-001003  127.03664 -0.16772  0.0762    326.571429
# 1     7991  eFEDSJ082840.6-000500  127.16920 -0.08355  0.3197   1370.142857
# 2     5601  eFEDSJ083110.5+015616  127.79401  1.93784  0.4195   1797.857143
# 3     2659  eFEDSJ083125.9+015533  127.85804  1.92590  0.6845   2933.571429
# 4     3725  eFEDSJ083137.9+004632  127.90807  0.77581  0.3023   1295.571429
# ..     ...                    ...        ...      ...     ...           ...
# 277   1761  eFEDSJ093546.3-000115  143.94326 -0.02110  0.3497   1498.714286
# 278  11748  eFEDSJ093707.4+034831  144.28102  3.80886  0.2709   1161.000000
# 279     38  eFEDSJ093712.8+031651  144.30357  3.28104  0.2474   1060.285714
# 280  10322  eFEDSJ093830.5+041523  144.62717  4.25640  0.2622   1123.714286
# 281   1594  eFEDSJ093938.3+042218  144.90960  4.37172  0.3687   1580.142857
#
#      cluster_radius_Mpc  cluster_volume_Mpc3  cluster_Velocity_Dispersion
# 0              0.664964             1.231640                    24.474377
# 1              0.598947             0.900021                    18.025137
# 2              0.924255             3.307227                  1239.911120
# 3              0.992066             4.089873                  2144.616872
# 4              0.698281             1.426195                   263.304854
# ..                  ...                  ...                          ...
# 277            0.810680             2.231704                   801.231382
# 278            0.788915             2.056743                   292.381823
# 279            0.681306             1.324693                   218.572810
# 280            0.672590             1.274498                   285.277474
# 281            0.783890             2.017686                  1630.714411
#
# [282 rows x 9 columns]

# %%
print(galaxy_df)
# Out:
#                   g_ID          RA       DEC        z
# 0      138021052006945  137.992346  2.570577  0.21327
# 1      130020205007803  130.790764  2.651356  0.29370
# 2      130990151906125  131.440319 -0.506608  0.15497
# 3      137020960805026  137.078359  2.389936  0.29276
# 4      141001088208416  140.558640  0.709116  0.08310
# ...                ...         ...       ...      ...
# 36796  130990634008739  130.986376 -0.260436  0.26954
# 36797  135021016609990  135.025604  2.857325  0.19924
# 36798  135000832810514  134.799377  0.906732  0.02531
# 36799  140000362709494  140.241766  0.810503  0.02381
# 36800  137021074202062  136.971637  2.110832  0.27823
#
# [36801 rows x 4 columns]

# %%
# Result of functions and updating the dataframes
cluster_df_updated, galaxy_df_updated = add_position_passed_galaxies_column(cluster_df, galaxy_df)
# Out:
# Cluster eFEDSJ082808.7-001003 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ082840.6-000500 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083110.5+015616 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083125.9+015533 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083137.9+004632 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083153.6+012530 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083204.4+041907 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083228.0-000656 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083315.5+000623 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083322.6-011128 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083330.4+050427 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083345.8+004208 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083412.7+035856 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083503.2+010756 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083651.3+030002 has 33 galaxies that passed positional comparison
# Cluster eFEDSJ083654.6+025954 has 36 galaxies that passed positional comparison
# Cluster eFEDSJ083723.6+012413 has 22 galaxies that passed positional comparison
# Cluster eFEDSJ083759.5-003643 has 9 galaxies that passed positional comparison
# Cluster eFEDSJ083802.9+015626 has 23 galaxies that passed positional comparison
# Cluster eFEDSJ083806.9-003600 has 9 galaxies that passed positional comparison
# Cluster eFEDSJ083807.6+002501 has 68 galaxies that passed positional comparison
# Cluster eFEDSJ083810.1+031520 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083817.4+041821 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083834.1+020643 has 15 galaxies that passed positional comparison
# Cluster eFEDSJ083857.5+020846 has 25 galaxies that passed positional comparison
# Cluster eFEDSJ083858.5-015032 has 57 galaxies that passed positional comparison
# Cluster eFEDSJ083859.3+022841 has 23 galaxies that passed positional comparison
# Cluster eFEDSJ083900.6+020057 has 16 galaxies that passed positional comparison
# Cluster eFEDSJ083903.5-011454 has 9 galaxies that passed positional comparison
# Cluster eFEDSJ083921.0-014149 has 46 galaxies that passed positional comparison
# Cluster eFEDSJ083929.0+043001 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ083930.3-014348 has 46 galaxies that passed positional comparison
# Cluster eFEDSJ083933.8-014044 has 52 galaxies that passed positional comparison
# Cluster eFEDSJ083937.8+014631 has 14 galaxies that passed positional comparison
# Cluster eFEDSJ083940.8+010416 has 73 galaxies that passed positional comparison
# Cluster eFEDSJ084000.0-013109 has 45 galaxies that passed positional comparison
# Cluster eFEDSJ084001.6+042452 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ084006.1+025913 has 9 galaxies that passed positional comparison
# Cluster eFEDSJ084021.6+020132 has 7 galaxies that passed positional comparison
# Cluster eFEDSJ084051.7+014122 has 15 galaxies that passed positional comparison
# Cluster eFEDSJ084102.1+044734 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ084105.5+031639 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ084129.0+002645 has 34 galaxies that passed positional comparison
# Cluster eFEDSJ084135.0+010150 has 2 galaxies that passed positional comparison
# Cluster eFEDSJ084142.9+002841 has 48 galaxies that passed positional comparison
# Cluster eFEDSJ084148.1+004911 has 113 galaxies that passed positional comparison
# Cluster eFEDSJ084151.3-003358 has 23 galaxies that passed positional comparison
# Cluster eFEDSJ084151.7+004351 has 12 galaxies that passed positional comparison
# Cluster eFEDSJ084220.9+013844 has 21 galaxies that passed positional comparison
# Cluster eFEDSJ084246.9-000917 has 28 galaxies that passed positional comparison
# Cluster eFEDSJ084307.1+002839 has 37 galaxies that passed positional comparison
# Cluster eFEDSJ084324.2-001438 has 26 galaxies that passed positional comparison
# Cluster eFEDSJ084346.2+010833 has 11 galaxies that passed positional comparison
# Cluster eFEDSJ084349.1+040404 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ084430.8+021736 has 177 galaxies that passed positional comparison
# Cluster eFEDSJ084454.0+010021 has 32 galaxies that passed positional comparison
# Cluster eFEDSJ084459.2-011902 has 6 galaxies that passed positional comparison
# Cluster eFEDSJ084501.0+012728 has 18 galaxies that passed positional comparison
# Cluster eFEDSJ084528.6+032739 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ084531.6+022831 has 79 galaxies that passed positional comparison
# Cluster eFEDSJ084544.3-002914 has 96 galaxies that passed positional comparison
# Cluster eFEDSJ084545.2+005535 has 14 galaxies that passed positional comparison
# Cluster eFEDSJ084558.1+012443 has 19 galaxies that passed positional comparison
# Cluster eFEDSJ084559.7+031321 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ084637.1-002256 has 16 galaxies that passed positional comparison
# Cluster eFEDSJ084640.3-010423 has 18 galaxies that passed positional comparison
# Cluster eFEDSJ084645.6+014947 has 191 galaxies that passed positional comparison
# Cluster eFEDSJ084647.4+044607 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ084649.0+004946 has 11 galaxies that passed positional comparison
# Cluster eFEDSJ084655.7-003705 has 13 galaxies that passed positional comparison
# Cluster eFEDSJ084717.7+033421 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ084751.7+025522 has 23 galaxies that passed positional comparison
# Cluster eFEDSJ084833.2-012216 has 5 galaxies that passed positional comparison
# Cluster eFEDSJ084905.3+021435 has 11 galaxies that passed positional comparison
# Cluster eFEDSJ084934.9+014437 has 28 galaxies that passed positional comparison
# Cluster eFEDSJ084939.6-005126 has 18 galaxies that passed positional comparison
# Cluster eFEDSJ085018.3+020018 has 16 galaxies that passed positional comparison
# Cluster eFEDSJ085020.4+032819 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ085022.2+001607 has 117 galaxies that passed positional comparison
# Cluster eFEDSJ085027.8+001503 has 120 galaxies that passed positional comparison
# Cluster eFEDSJ085030.5+003330 has 80 galaxies that passed positional comparison
# Cluster eFEDSJ085051.8+015331 has 24 galaxies that passed positional comparison
# Cluster eFEDSJ085119.9+022951 has 22 galaxies that passed positional comparison
# Cluster eFEDSJ085121.2+012856 has 16 galaxies that passed positional comparison
# Cluster eFEDSJ085130.0-004609 has 13 galaxies that passed positional comparison
# Cluster eFEDSJ085131.0+045239 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ085141.9+021438 has 54 galaxies that passed positional comparison
# Cluster eFEDSJ085204.5+012132 has 18 galaxies that passed positional comparison
# Cluster eFEDSJ085217.0-010131 has 9 galaxies that passed positional comparison
# Cluster eFEDSJ085230.6+002457 has 32 galaxies that passed positional comparison
# Cluster eFEDSJ085255.1-013737 has 19 galaxies that passed positional comparison
# Cluster eFEDSJ085327.2-002117 has 49 galaxies that passed positional comparison
# Cluster eFEDSJ085340.5+022411 has 71 galaxies that passed positional comparison
# Cluster eFEDSJ085419.5-000925 has 23 galaxies that passed positional comparison
# Cluster eFEDSJ085433.0+004009 has 132 galaxies that passed positional comparison
# Cluster eFEDSJ085436.6+003835 has 136 galaxies that passed positional comparison
# Cluster eFEDSJ085438.5+001211 has 30 galaxies that passed positional comparison
# Cluster eFEDSJ085447.0-012132 has 11 galaxies that passed positional comparison
# Cluster eFEDSJ085508.9-003445 has 48 galaxies that passed positional comparison
# Cluster eFEDSJ085517.2+013508 has 13 galaxies that passed positional comparison
# Cluster eFEDSJ085524.3+015012 has 37 galaxies that passed positional comparison
# Cluster eFEDSJ085541.2+002740 has 62 galaxies that passed positional comparison
# Cluster eFEDSJ085604.8+002520 has 69 galaxies that passed positional comparison
# Cluster eFEDSJ085623.6-013612 has 13 galaxies that passed positional comparison
# Cluster eFEDSJ085624.3+004632 has 18 galaxies that passed positional comparison
# Cluster eFEDSJ085626.2+021348 has 63 galaxies that passed positional comparison
# Cluster eFEDSJ085705.9+011453 has 73 galaxies that passed positional comparison
# Cluster eFEDSJ085728.3+032354 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ085751.6+031039 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ085801.1-004103 has 21 galaxies that passed positional comparison
# Cluster eFEDSJ085805.0+010906 has 227 galaxies that passed positional comparison
# Cluster eFEDSJ085830.0-010656 has 27 galaxies that passed positional comparison
# Cluster eFEDSJ085849.8+022800 has 26 galaxies that passed positional comparison
# Cluster eFEDSJ085901.5+010649 has 45 galaxies that passed positional comparison
# Cluster eFEDSJ085913.1+031334 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ085931.9+030839 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ085948.9+041120 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ085950.1-001221 has 11 galaxies that passed positional comparison
# Cluster eFEDSJ090010.4+023631 has 33 galaxies that passed positional comparison
# Cluster eFEDSJ090020.8-002602 has 2 galaxies that passed positional comparison
# Cluster eFEDSJ090034.1-010649 has 14 galaxies that passed positional comparison
# Cluster eFEDSJ090053.0-002837 has 6 galaxies that passed positional comparison
# Cluster eFEDSJ090059.3+035925 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ090104.4+011643 has 23 galaxies that passed positional comparison
# Cluster eFEDSJ090105.2-012525 has 15 galaxies that passed positional comparison
# Cluster eFEDSJ090115.3+005040 has 19 galaxies that passed positional comparison
# Cluster eFEDSJ090119.0+030204 has 42 galaxies that passed positional comparison
# Cluster eFEDSJ090129.1-013853 has 46 galaxies that passed positional comparison
# Cluster eFEDSJ090131.1+030056 has 45 galaxies that passed positional comparison
# Cluster eFEDSJ090133.2+021651 has 12 galaxies that passed positional comparison
# Cluster eFEDSJ090133.5-010540 has 9 galaxies that passed positional comparison
# Cluster eFEDSJ090137.7+030253 has 27 galaxies that passed positional comparison
# Cluster eFEDSJ090146.2-013756 has 41 galaxies that passed positional comparison
# Cluster eFEDSJ090200.5+022339 has 67 galaxies that passed positional comparison
# Cluster eFEDSJ090210.6+032513 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ090224.4-005150 has 16 galaxies that passed positional comparison
# Cluster eFEDSJ090248.5+044005 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ090255.2+030220 has 6 galaxies that passed positional comparison
# Cluster eFEDSJ090255.5+044036 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ090256.2+014625 has 98 galaxies that passed positional comparison
# Cluster eFEDSJ090257.4+004819 has 10 galaxies that passed positional comparison
# Cluster eFEDSJ090327.2+032545 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ090328.7-013622 has 20 galaxies that passed positional comparison
# Cluster eFEDSJ090333.8+043950 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ090409.7+003831 has 24 galaxies that passed positional comparison
# Cluster eFEDSJ090419.1-010436 has 18 galaxies that passed positional comparison
# Cluster eFEDSJ090540.0+043440 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ090600.3-002521 has 16 galaxies that passed positional comparison
# Cluster eFEDSJ090601.0+000055 has 50 galaxies that passed positional comparison
# Cluster eFEDSJ090609.4+042924 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ090628.9-012938 has 7 galaxies that passed positional comparison
# Cluster eFEDSJ090634.9+045033 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ090656.3+044717 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ090723.8-011210 has 17 galaxies that passed positional comparison
# Cluster eFEDSJ090739.7-010633 has 18 galaxies that passed positional comparison
# Cluster eFEDSJ090752.9+013407 has 77 galaxies that passed positional comparison
# Cluster eFEDSJ090803.8+020045 has 8 galaxies that passed positional comparison
# Cluster eFEDSJ090806.9+042351 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ090817.2-013034 has 17 galaxies that passed positional comparison
# Cluster eFEDSJ090838.0+015226 has 18 galaxies that passed positional comparison
# Cluster eFEDSJ090913.8-001214 has 26 galaxies that passed positional comparison
# Cluster eFEDSJ090916.0-015540 has 29 galaxies that passed positional comparison
# Cluster eFEDSJ090938.1+040816 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091011.7+013914 has 24 galaxies that passed positional comparison
# Cluster eFEDSJ091033.8+005100 has 10 galaxies that passed positional comparison
# Cluster eFEDSJ091057.2+041730 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091117.1+030441 has 7 galaxies that passed positional comparison
# Cluster eFEDSJ091214.1+022443 has 42 galaxies that passed positional comparison
# Cluster eFEDSJ091248.2+002446 has 25 galaxies that passed positional comparison
# Cluster eFEDSJ091302.1+035000 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091305.9+035021 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091315.0+034850 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091322.9+040617 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091331.0+024513 has 48 galaxies that passed positional comparison
# Cluster eFEDSJ091336.6+031723 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091351.1-004507 has 49 galaxies that passed positional comparison
# Cluster eFEDSJ091403.3+013846 has 59 galaxies that passed positional comparison
# Cluster eFEDSJ091412.6+001856 has 72 galaxies that passed positional comparison
# Cluster eFEDSJ091417.7+031159 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091423.9+022833 has 20 galaxies that passed positional comparison
# Cluster eFEDSJ091445.7+032755 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091446.1+001047 has 17 galaxies that passed positional comparison
# Cluster eFEDSJ091450.6-022606 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091453.6+041613 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091509.5+051521 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091512.2+043506 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091520.5+045203 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091555.6-013248 has 16 galaxies that passed positional comparison
# Cluster eFEDSJ091601.8+000831 has 10 galaxies that passed positional comparison
# Cluster eFEDSJ091609.4+013519 has 5 galaxies that passed positional comparison
# Cluster eFEDSJ091610.1-002348 has 47 galaxies that passed positional comparison
# Cluster eFEDSJ091612.9-015839 has 31 galaxies that passed positional comparison
# Cluster eFEDSJ091646.9+015531 has 14 galaxies that passed positional comparison
# Cluster eFEDSJ091722.4+010118 has 14 galaxies that passed positional comparison
# Cluster eFEDSJ091741.1+024518 has 4 galaxies that passed positional comparison
# Cluster eFEDSJ091749.4+014621 has 14 galaxies that passed positional comparison
# Cluster eFEDSJ091757.1+050915 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091849.0+021204 has 43 galaxies that passed positional comparison
# Cluster eFEDSJ091851.7+021432 has 37 galaxies that passed positional comparison
# Cluster eFEDSJ091858.0+024946 has 46 galaxies that passed positional comparison
# Cluster eFEDSJ091900.0+035311 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ091957.7+035012 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092022.8+045012 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092031.3+024710 has 42 galaxies that passed positional comparison
# Cluster eFEDSJ092037.0-011506 has 65 galaxies that passed positional comparison
# Cluster eFEDSJ092039.1+004725 has 17 galaxies that passed positional comparison
# Cluster eFEDSJ092046.2+002849 has 11 galaxies that passed positional comparison
# Cluster eFEDSJ092049.5+024513 has 55 galaxies that passed positional comparison
# Cluster eFEDSJ092053.4+021125 has 26 galaxies that passed positional comparison
# Cluster eFEDSJ092105.0+004452 has 33 galaxies that passed positional comparison
# Cluster eFEDSJ092121.2+031726 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092134.4+015832 has 22 galaxies that passed positional comparison
# Cluster eFEDSJ092135.4+005128 has 7 galaxies that passed positional comparison
# Cluster eFEDSJ092136.4-001449 has 45 galaxies that passed positional comparison
# Cluster eFEDSJ092202.2+034520 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092209.3+034628 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092212.0-002731 has 63 galaxies that passed positional comparison
# Cluster eFEDSJ092220.4+034806 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092235.8-002443 has 218 galaxies that passed positional comparison
# Cluster eFEDSJ092241.9+020719 has 44 galaxies that passed positional comparison
# Cluster eFEDSJ092246.2+034251 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092302.6+034002 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092339.0+052654 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092346.8-005330 has 33 galaxies that passed positional comparison
# Cluster eFEDSJ092402.2+054205 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092405.0-013059 has 16 galaxies that passed positional comparison
# Cluster eFEDSJ092409.4+040057 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092421.9-005103 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092454.7+014901 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092502.6+022612 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092504.3-005602 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092533.6-014205 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092546.3-014347 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092548.9-011725 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092555.6+004311 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092629.3+032614 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092639.7+040733 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092644.0+040010 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092647.5+050032 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092648.0+050124 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092650.5+035755 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092735.3+014423 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092737.7+020607 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092739.7-010427 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092740.1+042038 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092740.1-002922 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092740.7-015320 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092744.6+045630 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092813.0-004508 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092821.1+041941 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092821.2+042149 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092844.0+005318 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092846.5+000056 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092859.0+040532 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092910.2+022034 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092915.2+002427 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092915.7-001357 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092918.3+044925 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092928.3+042411 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ092955.8-003403 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093003.3+035630 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093009.0+040144 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093049.2-003714 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093056.9+034825 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093138.7-020933 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093151.3-002212 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093302.7-010145 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093403.5-001422 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093431.3-002309 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093436.1+051533 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093513.0+004757 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093520.7+003448 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093520.9+023234 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093522.2+032329 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093525.6+023445 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093531.4+022710 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093544.2-000339 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093546.3-000115 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093707.4+034831 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093712.8+031651 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093830.5+041523 has 0 galaxies that passed positional comparison
# Cluster eFEDSJ093938.3+042218 has 0 galaxies that passed positional comparison

# %%
clusters_with_galaxies_in_their_position = cluster_df_updated[cluster_df_updated['num_position_passed_galaxies'] > 0]
num_clusters_with_galaxies_in_their_position = len(clusters_with_galaxies_in_their_position)
print(f"Number of clusters with any number of galaxies within them after position filter: {num_clusters_with_galaxies_in_their_position}")
# Out:
# Number of clusters with any number of galaxies within them after position filter: 157

# %%
# Continue with the redshift filter
cluster_df_updated = add_z_passed_galaxies_column(cluster_df_updated, galaxy_df_updated)
# Out:
# Cluster eFEDSJ082808.7-001003 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ082840.6-000500 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083110.5+015616 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083125.9+015533 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083137.9+004632 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083153.6+012530 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083204.4+041907 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083228.0-000656 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083315.5+000623 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083322.6-011128 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083330.4+050427 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083345.8+004208 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083412.7+035856 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083503.2+010756 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083651.3+030002 has 7 galaxies that passed redshift comparison
# Cluster eFEDSJ083654.6+025954 has 11 galaxies that passed redshift comparison
# Cluster eFEDSJ083723.6+012413 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083759.5-003643 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083802.9+015626 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083806.9-003600 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083807.6+002501 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083810.1+031520 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083817.4+041821 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083834.1+020643 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ083857.5+020846 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083858.5-015032 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083859.3+022841 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083900.6+020057 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083903.5-011454 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083921.0-014149 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ083929.0+043001 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083930.3-014348 has 11 galaxies that passed redshift comparison
# Cluster eFEDSJ083933.8-014044 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ083937.8+014631 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ083940.8+010416 has 18 galaxies that passed redshift comparison
# Cluster eFEDSJ084000.0-013109 has 4 galaxies that passed redshift comparison
# Cluster eFEDSJ084001.6+042452 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084006.1+025913 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084021.6+020132 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084051.7+014122 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084102.1+044734 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084105.5+031639 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084129.0+002645 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ084135.0+010150 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084142.9+002841 has 7 galaxies that passed redshift comparison
# Cluster eFEDSJ084148.1+004911 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084151.3-003358 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084151.7+004351 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084220.9+013844 has 4 galaxies that passed redshift comparison
# Cluster eFEDSJ084246.9-000917 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ084307.1+002839 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ084324.2-001438 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084346.2+010833 has 3 galaxies that passed redshift comparison
# Cluster eFEDSJ084349.1+040404 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084430.8+021736 has 16 galaxies that passed redshift comparison
# Cluster eFEDSJ084454.0+010021 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084459.2-011902 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084501.0+012728 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ084528.6+032739 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084531.6+022831 has 6 galaxies that passed redshift comparison
# Cluster eFEDSJ084544.3-002914 has 10 galaxies that passed redshift comparison
# Cluster eFEDSJ084545.2+005535 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084558.1+012443 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ084559.7+031321 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084637.1-002256 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ084640.3-010423 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084645.6+014947 has 9 galaxies that passed redshift comparison
# Cluster eFEDSJ084647.4+044607 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084649.0+004946 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084655.7-003705 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ084717.7+033421 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084751.7+025522 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ084833.2-012216 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084905.3+021435 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ084934.9+014437 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ084939.6-005126 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085018.3+020018 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085020.4+032819 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085022.2+001607 has 42 galaxies that passed redshift comparison
# Cluster eFEDSJ085027.8+001503 has 36 galaxies that passed redshift comparison
# Cluster eFEDSJ085030.5+003330 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085051.8+015331 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ085119.9+022951 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ085121.2+012856 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085130.0-004609 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085131.0+045239 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085141.9+021438 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ085204.5+012132 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085217.0-010131 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085230.6+002457 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085255.1-013737 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ085327.2-002117 has 14 galaxies that passed redshift comparison
# Cluster eFEDSJ085340.5+022411 has 12 galaxies that passed redshift comparison
# Cluster eFEDSJ085419.5-000925 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085433.0+004009 has 8 galaxies that passed redshift comparison
# Cluster eFEDSJ085436.6+003835 has 20 galaxies that passed redshift comparison
# Cluster eFEDSJ085438.5+001211 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ085447.0-012132 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ085508.9-003445 has 10 galaxies that passed redshift comparison
# Cluster eFEDSJ085517.2+013508 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085524.3+015012 has 5 galaxies that passed redshift comparison
# Cluster eFEDSJ085541.2+002740 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085604.8+002520 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ085623.6-013612 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085624.3+004632 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085626.2+021348 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085705.9+011453 has 5 galaxies that passed redshift comparison
# Cluster eFEDSJ085728.3+032354 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085751.6+031039 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085801.1-004103 has 4 galaxies that passed redshift comparison
# Cluster eFEDSJ085805.0+010906 has 22 galaxies that passed redshift comparison
# Cluster eFEDSJ085830.0-010656 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ085849.8+022800 has 3 galaxies that passed redshift comparison
# Cluster eFEDSJ085901.5+010649 has 4 galaxies that passed redshift comparison
# Cluster eFEDSJ085913.1+031334 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085931.9+030839 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085948.9+041120 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ085950.1-001221 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090010.4+023631 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090020.8-002602 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090034.1-010649 has 3 galaxies that passed redshift comparison
# Cluster eFEDSJ090053.0-002837 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090059.3+035925 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090104.4+011643 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090105.2-012525 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ090115.3+005040 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090119.0+030204 has 6 galaxies that passed redshift comparison
# Cluster eFEDSJ090129.1-013853 has 8 galaxies that passed redshift comparison
# Cluster eFEDSJ090131.1+030056 has 13 galaxies that passed redshift comparison
# Cluster eFEDSJ090133.2+021651 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090133.5-010540 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090137.7+030253 has 3 galaxies that passed redshift comparison
# Cluster eFEDSJ090146.2-013756 has 4 galaxies that passed redshift comparison
# Cluster eFEDSJ090200.5+022339 has 15 galaxies that passed redshift comparison
# Cluster eFEDSJ090210.6+032513 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090224.4-005150 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090248.5+044005 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090255.2+030220 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090255.5+044036 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090256.2+014625 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090257.4+004819 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090327.2+032545 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090328.7-013622 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090333.8+043950 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090409.7+003831 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090419.1-010436 has 6 galaxies that passed redshift comparison
# Cluster eFEDSJ090540.0+043440 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090600.3-002521 has 3 galaxies that passed redshift comparison
# Cluster eFEDSJ090601.0+000055 has 13 galaxies that passed redshift comparison
# Cluster eFEDSJ090609.4+042924 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090628.9-012938 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ090634.9+045033 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090656.3+044717 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090723.8-011210 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090739.7-010633 has 4 galaxies that passed redshift comparison
# Cluster eFEDSJ090752.9+013407 has 24 galaxies that passed redshift comparison
# Cluster eFEDSJ090803.8+020045 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090806.9+042351 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ090817.2-013034 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ090838.0+015226 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ090913.8-001214 has 7 galaxies that passed redshift comparison
# Cluster eFEDSJ090916.0-015540 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ090938.1+040816 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091011.7+013914 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091033.8+005100 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091057.2+041730 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091117.1+030441 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091214.1+022443 has 1 galaxies that passed redshift comparison
# Cluster eFEDSJ091248.2+002446 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091302.1+035000 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091305.9+035021 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091315.0+034850 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091322.9+040617 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091331.0+024513 has 5 galaxies that passed redshift comparison
# Cluster eFEDSJ091336.6+031723 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091351.1-004507 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ091403.3+013846 has 13 galaxies that passed redshift comparison
# Cluster eFEDSJ091412.6+001856 has 4 galaxies that passed redshift comparison
# Cluster eFEDSJ091417.7+031159 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091423.9+022833 has 6 galaxies that passed redshift comparison
# Cluster eFEDSJ091445.7+032755 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091446.1+001047 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091450.6-022606 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091453.6+041613 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091509.5+051521 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091512.2+043506 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091520.5+045203 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091555.6-013248 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091601.8+000831 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091609.4+013519 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091610.1-002348 has 12 galaxies that passed redshift comparison
# Cluster eFEDSJ091612.9-015839 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091646.9+015531 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091722.4+010118 has 4 galaxies that passed redshift comparison
# Cluster eFEDSJ091741.1+024518 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091749.4+014621 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ091757.1+050915 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091849.0+021204 has 11 galaxies that passed redshift comparison
# Cluster eFEDSJ091851.7+021432 has 6 galaxies that passed redshift comparison
# Cluster eFEDSJ091858.0+024946 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091900.0+035311 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ091957.7+035012 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092022.8+045012 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092031.3+024710 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092037.0-011506 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ092039.1+004725 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092046.2+002849 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092049.5+024513 has 10 galaxies that passed redshift comparison
# Cluster eFEDSJ092053.4+021125 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092105.0+004452 has 5 galaxies that passed redshift comparison
# Cluster eFEDSJ092121.2+031726 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092134.4+015832 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092135.4+005128 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092136.4-001449 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ092202.2+034520 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092209.3+034628 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092212.0-002731 has 15 galaxies that passed redshift comparison
# Cluster eFEDSJ092220.4+034806 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092235.8-002443 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092241.9+020719 has 9 galaxies that passed redshift comparison
# Cluster eFEDSJ092246.2+034251 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092302.6+034002 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092339.0+052654 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092346.8-005330 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092402.2+054205 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092405.0-013059 has 2 galaxies that passed redshift comparison
# Cluster eFEDSJ092409.4+040057 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092421.9-005103 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092454.7+014901 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092502.6+022612 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092504.3-005602 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092533.6-014205 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092546.3-014347 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092548.9-011725 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092555.6+004311 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092629.3+032614 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092639.7+040733 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092644.0+040010 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092647.5+050032 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092648.0+050124 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092650.5+035755 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092735.3+014423 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092737.7+020607 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092739.7-010427 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092740.1+042038 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092740.1-002922 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092740.7-015320 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092744.6+045630 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092813.0-004508 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092821.1+041941 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092821.2+042149 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092844.0+005318 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092846.5+000056 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092859.0+040532 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092910.2+022034 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092915.2+002427 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092915.7-001357 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092918.3+044925 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092928.3+042411 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ092955.8-003403 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093003.3+035630 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093009.0+040144 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093049.2-003714 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093056.9+034825 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093138.7-020933 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093151.3-002212 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093302.7-010145 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093403.5-001422 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093431.3-002309 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093436.1+051533 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093513.0+004757 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093520.7+003448 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093520.9+023234 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093522.2+032329 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093525.6+023445 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093531.4+022710 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093544.2-000339 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093546.3-000115 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093707.4+034831 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093712.8+031651 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093830.5+041523 has 0 galaxies that passed redshift comparison
# Cluster eFEDSJ093938.3+042218 has 0 galaxies that passed redshift comparison

# %%
print(len(galaxy_df_updated['cluster_ID']))
print(len(cluster_df['position_passed_galaxies']))
print(len(cluster_df_updated['position_passed_']))
# Out:
# 36801
# 282
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'position_passed_'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 3
#       1 print(len(galaxy_df_updated['cluster_ID']))
#       2 print(len(cluster_df['position_passed_galaxies']))
# ----> 3 print(len(cluster_df_updated['position_passed_']))
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'position_passed_'

# %%
# Updating Galaxy dataframes

# In Galaxy dataframe remove the rows which their 'cluster_ID' is 'None'
galaxy_df_updated = galaxy_df_updated[galaxy_df_updated['cluster_ID'].notna()]

# Reset the index to clean index after the rows are removed
galaxy_df_updated.reset_index(drop=True, inplace=True)
print(len(galaxy_df_updated['cluster_ID']))

# %%
# Updating Galaxy dataframes

# Convert cluster_ID to the same dtype as c_ID for proper merging
galaxy_df_updated['cluster_ID'] = galaxy_df_updated['cluster_ID'].astype(cluster_df['c_ID'].dtype)

# Drop any existing 'c_NAME' columns to avoid conflicts during merge
columns_to_drop = [col for col in galaxy_df_updated.columns if 'c_NAME' in col]
galaxy_df_updated.drop(columns=columns_to_drop, inplace=True)

# Merge the DataFrame to add the cluster NAME
galaxy_df_updated = galaxy_df_updated.merge(cluster_df[['c_ID', 'c_NAME']], left_on='cluster_ID', right_on='c_ID', how='left')

# Drop the extra 'c_ID' column from the merge
galaxy_df_updated.drop(columns=['c_ID'], inplace=True)
print(len(galaxy_df_updated['cluster_ID']))

# %%
# Filter clusters to keep only those with galaxies that passed the redshift criteria
cluster_df_updated = cluster_df_updated[cluster_df_updated['num_passed_galaxies'] > 0].reset_index(drop=True)

# Update galaxy_df_updated to reflect only those galaxies within the filtered clusters
filtered_cluster_ids = cluster_df_updated['c_ID'].tolist()
galaxy_df_updated = galaxy_df_updated[galaxy_df_updated['cluster_ID'].isin(filtered_cluster_ids)].reset_index(drop=True)

# Display the updated DataFrame
print(galaxy_df_updated)
print(len(galaxy_df_updated['cluster_ID']))
